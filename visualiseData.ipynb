# %%
# %run parseData.ipynb

from matplotlib import pyplot as plt
import numpy as np

# %%
def VisualiseData(start=0, end=24, hand=0):
    x = []
    yx = []
    yy = []
    yz = []
    
    for data in all_data:
        label = data['label']
        if data['hand'] == hand:
            data_select = data['rot'][start:end]
            for bone in data_select:
                x.append(label)
                yx.append(bone[0])
                yy.append(bone[1])
                yz.append(bone[2])
    return x, yx, yy, yz

# %%
path = "./data/"

label_data, hand_data, all_data = read_data(path)

# %%
all_data[0]['rot'][0]
# Out:
# [0.75, 0.5, 0.75]

# %%
x, yx, yy, yz = VisualiseData(start=20, end=24)

plt.scatter(x=x, y=yx, color='r')
plt.scatter(x=x, y=yy, color='g')
plt.scatter(x=x, y=yz, color='b')

# %%
x, yx, yy, yz = VisualiseData(start=20, end=24, hand=1)

plt.scatter(x=x, y=yx, color='r')
plt.scatter(x=x, y=yy, color='g')
plt.scatter(x=x, y=yz, color='b')
